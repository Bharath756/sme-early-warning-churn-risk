# %% [markdown]
# # Time-Based Feature Engineering for Early Warning Churn
#
# ## Objective
# Engineer temporal and behavioral signals that indicate increasing churn risk
# before the actual churn event occurs.
